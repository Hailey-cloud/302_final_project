# %%
import pandas as pd
import numpy as np

# %%
cet_france = pd.read_csv('ECB Data Portal_France.csv')
cet_germany = pd.read_csv('ECB Data Portal_Germany.csv')
cet_spain = pd.read_csv('ECB Data Portal_Spain.csv')

# %%
cet_france.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39 entries, 0 to 38
# Data columns (total 3 columns):
#  #   Column                                                         Non-Null Count  Dtype
# ---  ------                                                         --------------  -----
#  0   DATE                                                           39 non-null     object
#  1   TIME PERIOD                                                    39 non-null     object
#  2   CET1 capital, SIs (SUP.Q.FR.W0._Z.O1100._T.SII._Z.ALL.LE.E.C)  39 non-null     float64
# dtypes: float64(1), object(2)
# memory usage: 1.0+ KB

# %%
cet_germany.head()
# Out:
#          DATE TIME PERIOD  \
# 0  2015-06-30      2015Q2
# 1  2015-09-30      2015Q3
# 2  2015-12-31      2015Q4
# 3  2016-03-31      2016Q1
# 4  2016-06-30      2016Q2
#
#    CET1 capital, SIs (SUP.Q.DE.W0._Z.O1100._T.SII._Z.ALL.LE.E.C)
# 0                                           168.9148
# 1                                           164.3765
# 2                                           199.9933
# 3                                           192.5293
# 4                                           193.7693

# %%
cet_spain.shape
# Out:
# (39, 3)

# %%
# Out:
#    Country  CET1_Avg
# 0   France    382.08
# 1  Germany    197.93
# 2    Spain    181.79

# %%
# for df in [cet_france, cet_germany, cet_spain]:
#     df.rename(columns={df.columns[2]: "CET1"}, inplace=True)


# cet_data = {
#     "France": cet_france,
#     "Germany": cet_germany,
#     "Spain": cet_spain
# }

# avg_df = pd.DataFrame({
#     "Country": list(cet_data.keys()),
#     "Average_CET1_Capital": [round(df["CET1"].mean(), 2) for df in cet_data.values()]
# })

# print(avg_df)
